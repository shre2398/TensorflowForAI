# %% [markdown]
# <a href="https://colab.research.google.com/github/shre2398/TensorflowForAI/blob/main/ProgrammingParadigm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - Installing Tensorflow

# %%
# !pip install tensorflow==2.0.0-alpha0
# Out:
# ...
#      |████████████████████████████████| 80.3MB 54kB/s
# ...
#      |████████████████████████████████| 51kB 4.4MB/s
# ...
#      |████████████████████████████████| 419kB 34.1MB/s
# ...
#      |████████████████████████████████| 3.0MB 33.9MB/s
# ...
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# ...

# %% [markdown]
# **Imports**

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# **Define and Compile Neural Network**

# %%
model = tf.keras.Sequential([(keras.layers.Dense(units=1, input_shape=[1]))])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# **Providing the data**

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# Training the Neural Network

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 0s 885us/sample - loss: 0.2495
# Epoch 2/500
# 6/6 [==============================] - 0s 278us/sample - loss: 0.2490
# Epoch 3/500
# 6/6 [==============================] - 0s 337us/sample - loss: 0.2485
# Epoch 4/500
# 6/6 [==============================] - 0s 351us/sample - loss: 0.2479
# Epoch 5/500
# 6/6 [==============================] - 0s 386us/sample - loss: 0.2474
# Epoch 6/500
# 6/6 [==============================] - 0s 478us/sample - loss: 0.2469
# Epoch 7/500
# 6/6 [==============================] - 0s 409us/sample - loss: 0.2464
# Epoch 8/500
# 6/6 [==============================] - 0s 486us/sample - loss: 0.2459
# Epoch 9/500
# 6/6 [==============================] - 0s 389us/sample - loss: 0.2454
# Epoch 10/500
# 6/6 [==============================] - 0s 910us/sample - loss: 0.2449
# Epoch 11/500
# 6/6 [==============================] - 0s 337us/sample - loss: 0.2444
# Epoch 12/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.121422]]
